# %%
# Importing necessary libraries to conduct our analysis
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
# Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")
from IPython.display import HTML,display

warnings.filterwarnings("ignore")

for dirname, _, filenames in os.walk('E:\TE_Project\datacsv'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# E:\TE_Project\datacsv\India.csv
# E:\TE_Project\datacsv\India1.csv
# E:\TE_Project\datacsv\India2.csv

# %%
#Reading the dataset into object 'df' using pandas:
df= pd.read_csv('E:/TE_Project/datacsv/India.csv',parse_dates=True)
df['date_time'] = pd.to_datetime(df['date_time'])

# %%
df.head(5)
# Out:
#    date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0 2015-01-01        24        11           0.0      8.7        5
# 1 2015-01-02        18        11           0.0      5.5        3
# 2 2015-01-03        19        13           0.0      8.7        5
# 3 2015-01-04        23        13           0.0      8.7        5
# 4 2015-01-05        21        10           0.0      8.7        5
#
#    moon_illumination  moonrise   moonset   sunrise  ... WindGustKmph  \
# 0                 72  02:39 PM  03:24 AM  07:14 AM  ...           10
# 1                 80  03:27 PM  04:21 AM  07:14 AM  ...           15
# 2                 87  04:16 PM  05:16 AM  07:15 AM  ...            8
# 3                 94  05:08 PM  06:08 AM  07:15 AM  ...           18
# 4                100  06:01 PM  06:57 AM  07:15 AM  ...           23
#
#    cloudcover  humidity  precipMM  pressure  tempC  visibility  winddirDegree  \
# ...

# %%
df.describe()
# Out:
#           maxtempC     mintempC  totalSnow_cm      sunHour      uvIndex  \
# count  2009.000000  2009.000000        2009.0  2009.000000  2009.000000
# mean     34.509706    25.330015           0.0    11.280040     7.508213
# std       7.246446     7.604786           0.0     2.145863     1.605536
# min      15.000000     8.000000           0.0     3.800000     3.000000
# 25%      29.000000    19.000000           0.0     8.700000     6.000000
# 50%      36.000000    27.000000           0.0    11.600000     8.000000
# 75%      40.000000    31.000000           0.0    13.300000     9.000000
# max      51.000000    42.000000           0.0    14.000000    11.000000
#
#        moon_illumination    DewPointC   FeelsLikeC   HeatIndexC   WindChillC  \
# count        2009.000000  2009.000000  2009.000000  2009.000000  2009.000000
# mean           46.121951    11.033848    30.985565    31.042310    29.828771
# std            31.299583     7.793452     8.721984     8.632417     7.624632
# ...

# %%
column16= 'TEMP'

# %%
df=df.astype('float64')
df=df.resample(rule='MS').mean()
# Out:
# ---------------------------------------------------------------------
# ValueError                          Traceback (most recent call last)
# <ipython-input-67-18704d37818a> in <module>
# ----> 1 df=df.astype('float64')
#       2 df=df.resample(rule='MS').mean()
#
# c:\users\muskan\appdata\local\programs\python\python36\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5546         else:
#    5547             # else, only a single dtype is given
# -> 5548             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5549             return self._constructor(new_data).__finalize__(self, method="astype")
#    5550
#
# c:\users\muskan\appdata\local\programs\python\python36\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     602         self, dtype, copy: bool = False, errors: str = "raise"
#     603     ) -> "BlockManager":
# ...

# %%
auto_arima(y=tempC,start_p=0,start_P=0,start_q=0,start_Q=0,seasonal=True, m=12).summary()
# Out:
# ---------------------------------------------------------------------
# NameError                           Traceback (most recent call last)
# <ipython-input-60-f585ba856f0e> in <module>
# ----> 1 auto_arima(y=tempC,start_p=0,start_P=0,start_q=0,start_Q=0,seasonal=True, m=12).summary()
#
# NameError: name 'tempC' is not defined

# %%
# Out:
# ---------------------------------------------------------------------
# TypeError                           Traceback (most recent call last)
# <ipython-input-53-0ddbbd989d61> in <module>
# ----> 1 final_df=pd.DataFrame(index=np.arange('2015-01-01','2020-07-02',dtype='datetime64[D]'),columns=column1)
#       2 print(final_df.shape)
#
# c:\users\muskan\appdata\local\programs\python\python36\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# c:\users\muskan\appdata\local\programs\python\python36\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     245         from pandas.core.series import Series  # noqa:F811
#     246
# ...
